# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/diamonds.csv")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
Dicionario = pd.DataFrame([
    {
        "Variavel": "carat",
        "Descricao": "Peso do diamante",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "cut",
        "Descricao": "Qualidade do corte",
        "Tipo": "Qualitativo",
        "Subtipo:": "Ordinal"
    },{
        "Variavel": "color",
        "Descricao": "Cor do diamante",
        "Tipo": "Qualitativo",
        "Subtipo:": "Ordinal"
    },{
        "Variavel": "clarity",
        "Descricao": "Medida do quão limpo esta o diamante",
        "Tipo": "Qualitativo",
        "Subtipo:": "Ordinal"
    },{
        "Variavel": "depht",
        "Descricao": "Porcentagem total de profundidade",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "table",
        "Descricao": "Largura do topo do diamante em relação ao ponto mais largo",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "price",
        "Descricao": "Preco do diamante em dolares",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "x",
        "Descricao": "Comprimento em mm",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "y",
        "Descricao": "largura em mm",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    },{
        "Variavel": "z",
        "Descricao": "profundidade em mm",
        "Tipo": "Quantitativo",
        "Subtipo:": "Continua"
    }

])
Dicionario.to_csv("../data/external/dictionary.csv", index = False)
Dicionario
# Out:
#   Variavel                                          Descricao          Tipo  \
# 0    carat                                   Peso do diamante  Quantitativo
# 1      cut                                 Qualidade do corte   Qualitativo
# 2    color                                    Cor do diamante   Qualitativo
# 3  clarity               Medida do quão limpo esta o diamante   Qualitativo
# 4    depht                  Porcentagem total de profundidade  Quantitativo
# 5    table  Largura do topo do diamante em relação ao pont...  Quantitativo
# 6    price                       Preco do diamante em dolares  Quantitativo
# 7        x                                  Comprimento em mm  Quantitativo
# 8        y                                      largura em mm  Quantitativo
# 9        z                                 profundidade em mm  Quantitativo
#
#    Subtipo:
# 0  Continua
# 1   Ordinal
# 2   Ordinal
# 3   Ordinal
# 4  Continua
# 5  Continua
# 6  Continua
# 7  Continua
# ...
